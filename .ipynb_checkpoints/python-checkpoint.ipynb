# %%
x = input()
y = input()
print(x*y)
# Out:
#  3
#  4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 x = input()
#       2 y = input()
# ----> 3 print(x*y)
#
# TypeError: can't multiply sequence by non-int of type 'str'
